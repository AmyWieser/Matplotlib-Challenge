# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merge_df = pd.merge(study_results, mouse_metadata, on = "Mouse ID", how = "left")

# Display the data table for preview
merge_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
count_mice = merge_df["Mouse ID"].count()
count_mice
# Out:
# 1893

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
dup_mice = merge_df[merge_df.duplicated(['Mouse ID', 'Timepoint'])]
print("Duplicate Rows based on Mouse ID and Timepoint:")
dup_mice
# Out:
# Duplicate Rows based on Mouse ID and Timepoint:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 137      g989          0           45.000000                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 1111     g989         20           54.657650                 1     Propriva
#
#          Sex  Age_months  Weight (g)
# 137   Female          21          26
# 360   Female          21          26
# 681   Female          21          26
# 869   Female          21          26
# 1111  Female          21          26

# %%
# Optional: Get all the data for the duplicate mouse ID. 
dup_mice_all = merge_df[merge_df.duplicated(['Mouse ID'])]
print("Duplicate Rows based on Mouse ID:")
dup_mice_all
# Out:
# Duplicate Rows based on Mouse ID:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 137      g989          0           45.000000                 0     Propriva
# 250      a275          5           46.795257                 0     Ceftamin
# 251      w575          5           48.913860                 1    Zoniferol
# 252      x822          5           45.671104                 1     Ceftamin
# 253      l509          5           45.851193                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_df = merge_df.drop_duplicates("Mouse ID", keep = "first")
cleaned_df
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       b128          0                45.0                 0    Capomulin
# 1       f932          0                45.0                 0     Ketapril
# 2       g107          0                45.0                 0     Ketapril
# 3       a457          0                45.0                 0     Ketapril
# 4       c819          0                45.0                 0     Ketapril
# ..       ...        ...                 ...               ...          ...
# 245     t565          0                45.0                 0    Capomulin
# 246     i557          0                45.0                 0    Capomulin
# 247     m957          0                45.0                 0    Capomulin
# 248     f966          0                45.0                 0    Capomulin
# 249     m601          0                45.0                 0    Capomulin
#
#         Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
count_mice_cleaned = cleaned_df["Mouse ID"].count()
count_mice_cleaned
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

#Groupby Regimen
regimen_total = merge_df.groupby("Drug Regimen")
regimen_total

#Calculations
summary_mean = regimen_total["Tumor Volume (mm3)"].mean()
summary_median = regimen_total["Tumor Volume (mm3)"].median()
summary_variance = regimen_total["Tumor Volume (mm3)"].var()
summary_stdev = regimen_total["Tumor Volume (mm3)"].std()
summary_sem = regimen_total["Tumor Volume (mm3)"].sem()

#Create Dataframe
summary_df = pd.DataFrame({"Mean":summary_mean,
                           "Median":summary_median,
                           "Variance":summary_variance,
                           "Std Dev":summary_stdev,
                           "SEM":summary_sem
                          })

summary_df
# Out:
#                    Mean     Median   Variance   Std Dev       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

summary_tbl = regimen_total.agg(['mean','median','var','std','sem'])["Tumor Volume (mm3)"]
summary_tbl
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
# Count how many measurements were taken on each regimen
measurement_count = regimen_total["Mouse ID"].count()
measurement_df = pd.DataFrame({"# of Measurements":measurement_count})
measurement_df
# Out:
#               # of Measurements
# Drug Regimen
# Capomulin                   230
# Ceftamin                    178
# Infubinol                   178
# Ketapril                    188
# Naftisol                    186
# Placebo                     181
# Propriva                    161
# Ramicane                    228
# Stelasyn                    181
# Zoniferol                   182

# %%
# Create a bar chart from the dataframe
bar_chart = measurement_count.plot(kind="bar", title = "Number of Measurements Taken by Drug Regimen", color = "blue")
plt.ylabel("Number of Measurements")
plt.xlabel("Drug Regimen")
plt.show()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.

# Count how many measurements were taken on each regimen
measurement_count = regimen_total["Mouse ID"].count()
measurement_df = pd.DataFrame({"# of Measurements":measurement_count})

# Set x axis and tick locations
x_axis = np.arange(len(measurement_count))
tick_locations = [value for value in x_axis]

# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(6,4))
plt.bar(x_axis, measurement_count, color='blue', align="center", width=.50)
plt.xticks(tick_locations, list(measurement_count.index), rotation="vertical")

# Set x and y limits
plt.xlim(-0.75, len(x_axis)-.25)
plt.ylim(0, max(measurement_count)*1.05)

# Set a Title and labels
plt.title("Number of Measurements Taken by Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Measurements")
# Out:
# Text(0, 0.5, 'Number of Measurements')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# Count Mice by Gender
gender_group = merge_df.groupby("Sex")
gender_group_df = pd.DataFrame(gender_group["Sex"].count())
gender_group_df
# Out:
#         Sex
# Sex
# Female  935
# Male    958

# %%
# Create Pie Graph
pie_chart = gender_group_df.plot(kind="pie", y="Sex",title = "Male vs Female Mice", 
                              startangle = 120, autopct='%1.1f%%', shadow=True, 
                              fontsize=12, colors=("green","gold"), legend=False)

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

gender_counts = gender_group_df["Sex"]
genders = list(gender_group_df.index.values)
colors = ["green", "gold"]

plt.title("Male vs Female Mice")
plt.pie(gender_counts, labels=genders, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=120)
plt.axis("equal")
plt.ylabel("Sex")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  

# Create list for: Capomulin, Ramicane, Infubinol, and Ceftamin
selected_drug_list = merge_df[merge_df["Drug Regimen"].isin(["Capomulin", "Ramicane", "Infubinol", "Ceftamin"])]

# Sort above list by Timepoint
selected_drug_list = selected_drug_list.sort_values(["Mouse ID","Timepoint"], ascending=False)

# Start by getting the last (greatest) timepoint for each mouse (Keep first value from sorted list)
final_tumor = selected_drug_list.drop_duplicates(subset=["Mouse ID"], keep="first")

# Create Dataframe with only columns necessary
final_tumor_df = final_tumor[["Drug Regimen", "Mouse ID", "Timepoint", "Tumor Volume (mm3)"]]

# Rename column for Final Tumor Volume
final_tumor_df = final_tumor_df.rename(columns = {"Tumor Volume (mm3)":"Final Tumor Volume"})

# Resort dataframe by Drug Regimen and Mouse ID
final_tumor_sorted = final_tumor_df.sort_values(["Drug Regimen", "Mouse ID"], ascending=True)

final_tumor_sorted
# Out:
#      Drug Regimen Mouse ID  Timepoint  Final Tumor Volume
# 1764    Capomulin     b128         45           38.982878
# 1829    Capomulin     b742         45           38.939633
# 930     Capomulin     f966         20           30.485985
# 1777    Capomulin     g288         45           37.074024
# 1791    Capomulin     g316         45           40.159220
# ...           ...      ...        ...                 ...
# 1795     Ramicane     s508         45           30.276232
# 1867     Ramicane     u196         45           40.667713
# 424      Ramicane     w678          5           43.166373
# 734      Ramicane     y449         15           44.183451
# 1799     Ramicane     z578         45           30.638696
#
# [100 rows x 4 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]


# For Loop..
for x in treatments:
    tumor_vol = merge_df.loc[merge_df["Drug Regimen"] == x,["Drug Regimen","Tumor Volume (mm3)"]]
    quartiles = tumor_vol["Tumor Volume (mm3)"].quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
   
      
    print(f"The lower quartile of {x} is: {lowerq}")
    print(f"The upper quartile of {x} is: {upperq}")
    print(f"The IQR of {x} is: {iqr}")
    
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    
    print(f"Values below {lower_bound} could be outliers.")
    print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Capomulin is: 37.685932865
# The upper quartile of Capomulin is: 45.0
# The IQR of Capomulin is: 7.314067135000002
# Values below 26.714832162499995 could be outliers.
# Values above 55.9711007025 could be outliers.
# The lower quartile of Ramicane is: 36.67463458499999
# The upper quartile of Ramicane is: 45.0
# The IQR of Ramicane is: 8.325365415000007
# Values below 24.18658646249998 could be outliers.
# Values above 57.48804812250001 could be outliers.
# The lower quartile of Infubinol is: 47.3123533
# The upper quartile of Infubinol is: 57.314443967500004
# The IQR of Infubinol is: 10.002090667500006
# Values below 32.309217298749985 could be outliers.
# Values above 72.31757996875001 could be outliers.
# The lower quartile of Ceftamin is: 47.208427112500004
# The upper quartile of Ceftamin is: 56.801437570000004
# The IQR of Ceftamin is: 9.5930104575
# Values below 32.818911426250004 could be outliers.
# Values above 71.19095325625 could be outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# For Loop..
for x in treatments:
    tumor_vol = merge_df.loc[merge_df["Drug Regimen"] == x,["Drug Regimen","Tumor Volume (mm3)"]]
    fig1, ax1 = plt.subplots()
    ax1.set_title("Final Tumor Volume by Drug Regimen")
    ax1.set_ylabel("Final Tumor Volumes (mm3)")
    ax1.boxplot(tumor_vol["Tumor Volume (mm3)"])
    
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
# Define x axis
timepoint = final_tumor_sorted["Timepoint"]

#merge_df.loc[merge_df["Drug Regimen"] == x,["Drug Regimen","Tumor Volume (mm3)"]]

#Define y axis
tumor_vol_b128 = final_tumor_sorted.Loc[final_tumor_sorted["Mouse ID"] == ["b128"],["Final Tumor Volume"]

# Create line chart
plt.plot(timepoint, tumor_vol_b128 , color="blue", label="Tumor Vol over Days for Mouse b128")

                                        
plt.title(treatments + "'s treatment of mouse I509")
plt.xlabel("Timepoint (days)")
plt.xticks(np.arange(min(timepoint), max(timepoint)+1, 1.0))
plt.ylabel("Tumor Volume (mm3)")

# Print our chart to the screen
plt.show()
# Out:
#   File "<ipython-input-282-1936eba65386>", line 11
#     plt.plot(timepoint, tumor_vol_b128 , color="blue", label="Tumor Vol over Days for Mouse b128")
#     ^
# SyntaxError: invalid syntax

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
